# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key



# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Out:
# Requirement already satisfied: citipy in c:\users\kaoti\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kaoti\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
cities
# Out:
# ['ixtapa',
#  'jamestown',
#  'bafq',
#  'kijang',
#  'ostrovnoy',
#  'hualmay',
#  'vaini',
#  'hasaki',
#  'isabela',
#  'lerwick',
#  'greencastle',
#  'umzimvubu',
#  'rikitea',
#  'atambua',
#  'zanjan',
#  'hermanus',
#  'chara',
#  'atuona',
#  'ust-karsk',
#  'pevek',
#  'bethel',
#  'hamilton',
#  'bambous virieux',
#  'san carlos de bariloche',
#  'provideniya',
#  'santa maria',
#  'cape town',
#  'georgetown',
#  'upernavik',
#  'highland',
#  'busselton',
#  'port alfred',
#  'merrill',
#  'lagoa',
#  'mataura',
#  'benito juarez',
#  'iqaluit',
#  'marquette',
#  'vaitupu',
#  'ushuaia',
#  'chalmette',
#  'bluff',
#  'shar',
#  'nikolskoye',
#  'san quintin',
#  'belushya guba',
#  'sao joao da barra',
#  'san joaquin',
#  'tiksi',
#  'bathsheba',
#  'new norfolk',
#  'fort wellington',
#  'moranbah',
#  'punta arenas',
#  'hithadhoo',
#  'seoul',
#  'batagay-alyta',
#  'kayerkan',
#  'caravelas',
#  'manzhouli',
#  'buraydah',
#  'carnarvon',
#  'esperance',
#  'port hedland',
#  'talnakh',
#  'isangel',
#  'kavieng',
#  'linxia',
#  'paysandu',
#  'sitka',
#  'khatanga',
#  'port hardy',
#  'ribeira grande',
#  'qaanaaq',
#  'sioux lookout',
#  'geraldton',
#  'barra do garcas',
#  'bengkulu',
#  'san cristobal',
#  'luderitz',
#  'zalaegerszeg',
#  'tuktoyaktuk',
#  'birao',
#  'vao',
#  'klaksvik',
#  'mount gambier',
#  'manado',
#  'palabuhanratu',
#  'kaeo',
#  'clyde river',
#  'altamont',
#  'espanola',
#  'polyarnyy',
#  'los negros',
#  'hobart',
#  'dawei',
#  'thompson',
#  'kodiak',
#  'lethem',
#  'hilo',
#  'pitimbu',
#  'saskylakh',
#  'mar del plata',
#  'dikson',
#  'vardo',
#  'mahebourg',
#  'port macquarie',
#  'acajutla',
#  'praia da vitoria',
#  'bassila',
#  'adjumani',
#  'viligili',
#  'avarua',
#  'kroya',
#  'moose factory',
#  'imeni stepana razina',
#  'shchelyayur',
#  'horta',
#  'east london',
#  'port moresby',
#  'bokspits',
#  'karratha',
#  'trat',
#  'hanzhong',
#  'codrington',
#  'jalu',
#  'mackay',
#  'tateyama',
#  'aitape',
#  'yellowknife',
#  'la roda',
#  'dinghai',
#  'katsuura',
#  'albany',
#  'severo-kurilsk',
#  'taolanaro',
#  'mount isa',
#  'lexington',
#  'sarahan',
#  'saint george',
#  'grand river south east',
#  'sakaraha',
#  'lufkin',
#  'banos',
#  'bukachacha',
#  'souillac',
#  'sinnamary',
#  'sentyabrskiy',
#  'troitskoye',
#  'olafsvik',
#  'zalantun',
#  'sedan',
#  'qiongshan',
#  'walvis bay',
#  'kudahuvadhoo',
#  'garden city',
#  'ilulissat',
#  'saint-philippe',
#  'shorapur',
#  'barentsburg',
#  'lompoc',
#  'torbay',
#  'noumea',
#  'samusu',
#  'chokurdakh',
#  'fairview',
#  'placerville',
#  'banjarmasin',
#  'castro',
#  'lar gerd',
#  'shingu',
#  'akdepe',
#  'illoqqortoormiut',
#  'benguela',
#  'tautira',
#  'tovste',
#  'sao filipe',
#  'amderma',
#  'saint-francois',
#  'andros town',
#  'salinopolis',
#  'hofn',
#  'carutapera',
#  'port elizabeth',
#  'syamzha',
#  'arraial do cabo',
#  'kavaratti',
#  'fairbanks',
#  'tabou',
#  'butaritari',
#  'gravelbourg',
#  'puerto ayora',
#  'yulara',
#  'cherskiy',
#  'tsihombe',
#  'pedernales',
#  'adrar',
#  'sao jose da coroa grande',
#  'saldanha',
#  'angoram',
#  'belaya gora',
#  'lebu',
#  'atbasar',
#  'gimli',
#  'grindavik',
#  'tocopilla',
#  'llanes',
#  'severnyy',
#  'aswan',
#  'tasiilaq',
#  'beidao',
#  'doka',
#  'borlange',
#  'otjimbingwe',
#  'urambo',
#  'lerum',
#  'dzhusaly',
#  'kapaa',
#  'nizhneyansk',
#  'victoria',
#  'kaitangata',
#  'valdivia',
#  'eirunepe',
#  'saint-augustin',
#  'tarko-sale',
#  'malindi',
#  'dolgoye',
#  'salsk',
#  'lazaro cardenas',
#  'sabzevar',
#  'callaway',
#  'haines junction',
#  'nuevo progreso',
#  'chicama',
#  'bulgan',
#  'uk',
#  'paita',
#  'necochea',
#  'haibowan',
#  'rio grande',
#  'japura',
#  'kamennomostskiy',
#  'jiwani',
#  'longyearbyen',
#  'san patricio',
#  'plettenberg bay',
#  'fredericksburg',
#  'mayumba',
#  'sao felix do xingu',
#  'pitkyaranta',
#  'teahupoo',
#  'jabinyanah',
#  'kupang',
#  'port blair',
#  'victoria point',
#  'bur gabo',
#  'naron',
#  'tatui',
#  'bredasdorp',
#  'jiaojiang',
#  'changli',
#  'muisne',
#  'aklavik',
#  'timra',
#  'herat',
#  'udachnyy',
#  'omsukchan',
#  'hay river',
#  'zverinogolovskoye',
#  'barrow',
#  'jyvaskyla',
#  'borogontsy',
#  'chuy',
#  'harper',
#  'vaitape',
#  'pedro ii',
#  'vila do maio',
#  'lolua',
#  'atar',
#  'kieta',
#  'ahipara',
#  'qingquan',
#  'kirkwall',
#  'acapulco',
#  'lahad datu',
#  'andra',
#  'vestmannaeyjar',
#  'vanimo',
#  'veracruz',
#  'barinas',
#  'jahazpur',
#  'gat',
#  'erenhot',
#  'loandjili',
#  'college',
#  'harrogate',
#  'airai',
#  'yatou',
#  'mouzakion',
#  'richards bay',
#  'erzin',
#  'jiangyou',
#  'komsomolskiy',
#  'morgan city',
#  'husavik',
#  'rosetta',
#  'iranshahr',
#  'korla',
#  'bambanglipuro',
#  'winnemucca',
#  'cuamba',
#  'vila velha',
#  'pisco',
#  'malwan',
#  'ballitoville',
#  'amapa',
#  'yarada',
#  'nanortalik',
#  'we',
#  'areni',
#  'srednekolymsk',
#  'beboto',
#  'rzhev',
#  'saint-georges',
#  'bubaque',
#  'cayenne',
#  'choma',
#  'prince rupert',
#  'la ferte-bernard',
#  'high prairie',
#  'avera',
#  'broken hill',
#  'gamboula',
#  'viesca',
#  'kiruna',
#  'carmo do paranaiba',
#  'kahului',
#  'akyab',
#  'union de san antonio',
#  'la tuque',
#  'ishigaki',
#  'cacapava do sul',
#  'madiun',
#  'ponta do sol',
#  'fortuna',
#  'rawson',
#  'akcakoca',
#  'uige',
#  'praia',
#  'sorong',
#  'mafeteng',
#  'marawi',
#  'elko',
#  'daru',
#  'touros',
#  'tazovskiy',
#  'kadoma',
#  'marzuq',
#  'te anau',
#  'nakama',
#  'amga',
#  'catio',
#  'aykhal',
#  'grafton',
#  'dingle',
#  'nome',
#  'minbu',
#  'pak phanang',
#  'pacific grove',
#  'leningradskiy',
#  'kyra',
#  'buala',
#  'san isidro',
#  'redwater',
#  'hovd',
#  'vangaindrano',
#  'thinadhoo',
#  'inverell',
#  'peoria',
#  'yumen',
#  'gillette',
#  'manosque',
#  'flagstaff',
#  'kaniama',
#  'namatanai',
#  'vernon',
#  'quatre cocos',
#  'carballo',
#  'qabis',
#  'monte alegre',
#  'bodmin',
#  'miguel calmon',
#  'lasa',
#  'tupik',
#  'camacha',
#  'ituacu',
#  'comodoro rivadavia',
#  'rio gallegos',
#  'dom pedro',
#  'guerrero negro',
#  'zelenogorskiy',
#  'mys shmidta',
#  'gizo',
#  'chapais',
#  'alekseyevsk',
#  'krasnomayskiy',
#  'dongsheng',
#  'the valley',
#  'gawler',
#  'clonakilty',
#  'sayyan',
#  'miri',
#  'jishou',
#  'smithers',
#  'narsaq',
#  'mathathane',
#  'ihosy',
#  'nanuque',
#  'pouebo',
#  'oktyabrskiy',
#  'hami',
#  'oistins',
#  'westport',
#  'kenai',
#  'alofi',
#  'saleaula',
#  'alotau',
#  'coquimbo',
#  'castricum',
#  'fukue',
#  'shostka',
#  'ndago',
#  'helong',
#  'chirongui',
#  'salalah',
#  'mashhad',
#  'abu samrah',
#  'kapit',
#  'zhongshan',
#  'north bend',
#  'kralendijk',
#  'kharhial',
#  'taksimo',
#  'gonaives',
#  'luang prabang',
#  'beira',
#  'hihifo',
#  'dayong',
#  'marrakesh',
#  'petropavlovka',
#  'bellevue',
#  'dwarka',
#  'umm lajj',
#  'aflu',
#  'sandnessjoen',
#  'kropotkin',
#  'ancud',
#  'half moon bay',
#  'tumannyy',
#  'miracema do tocantins',
#  'nyurba',
#  'bonfim',
#  'okandja',
#  'kruisfontein',
#  'rokytne',
#  'olinda',
#  'nanakuli',
#  'muroto',
#  'karaton',
#  'tual',
#  'coihueco',
#  'dujuma',
#  'ca mau',
#  'sosnogorsk',
#  'abu kamal',
#  'skjervoy',
#  'boa viagem',
#  'puerto leguizamo',
#  'ermua',
#  'lubango',
#  'tura',
#  'faanui',
#  'urucui',
#  'nassjo',
#  'stromness',
#  'mehamn',
#  'vila franca do campo',
#  'mackenzie',
#  'deputatskiy',
#  'byron bay',
#  'bangui',
#  'yar-sale',
#  'guajara-mirim',
#  'krasnoselkup',
#  'staroutkinsk',
#  'muros',
#  'yanan',
#  'weyburn',
#  'bolungarvik',
#  'mmathubudukwane',
#  'sorland',
#  'saint-pierre',
#  'twentynine palms',
#  'kysyl-syr',
#  'lufilufi',
#  'bulancak',
#  'nurpur',
#  'scarborough',
#  'samalaeulu',
#  'roald',
#  'omboue',
#  'cidreira',
#  'trincomalee',
#  'kuryk',
#  'kloulklubed',
#  'ferme-neuve',
#  'rungata',
#  'bandundu',
#  'arman',
#  'kawalu',
#  'sembe',
#  'marcona',
#  'norman wells',
#  'soma',
#  'mattru',
#  'cabedelo',
#  'kholodnyy',
#  'riyadh',
#  'new amsterdam',
#  'urumqi',
#  'saint anthony',
#  'attawapiskat',
#  'novosheshminsk',
#  'erie',
#  'nizwa',
#  'aktash',
#  'maridi',
#  'poitiers',
#  'tarudant',
#  'biskamzha',
#  'cedar city',
#  'siniscola',
#  'dumra',
#  'tabuk',
#  'karaul',
#  'jinchang',
#  'shenjiamen',
#  'zyryanka',
#  'asau',
#  'kirakira',
#  'pangnirtung',
#  'zmeinogorsk',
#  'broome',
#  'ewa beach',
#  'mogadishu',
#  'grand centre',
#  'salamiyah',
#  'banda aceh',
#  'la ronge',
#  'cap-aux-meules',
#  'sur',
#  'ballina',
#  'piacabucu',
#  'crixas',
#  'waspan',
#  'zhangjiakou',
#  'zvenigovo',
#  'madikeri',
#  'lorengau',
#  'livingstonia',
#  'aginskoye',
#  'goundam',
#  'okhotsk',
#  'labuhan',
#  'galle',
#  'batagay',
#  'yeniseysk',
#  'high wycombe',
#  'zhezkazgan',
#  'totness',
#  'west bay',
#  'baghdad',
#  'belmonte',
#  'tubuala',
#  'arlit',
#  'dhanaula',
#  'amot',
#  'calabozo',
#  'vostok',
#  'road town',
#  'oussouye',
#  'biak',
#  'constitucion',
#  'council bluffs',
#  'najran',
#  'maceio',
#  'san lorenzo',
#  'along',
#  'malanje',
#  'qaqortoq',
#  'srandakan',
#  'portland',
#  'mayfield',
#  'sibolga',
#  'pierre']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set query url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="



# create lists for storage in dataframe
api_city = []
api_lng = []
api_lat = []
api_cloud = []
api_temp_max = []
api_humidity = []
api_wspeed = []
api_country = []
api_date = []

# set initial count quantities for organization
counter_1 = 0
counter_2 = 1

# for loop to create columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        api_lng.append(response['coord']['lon'])
        api_lat.append(response['coord']['lat'])
        api_cloud.append(response['clouds']['all'])
        api_temp_max.append(response['main']['temp_max'])
        api_humidity.append(response['main']['humidity'])
        api_wspeed.append(response['wind']['speed'])
        api_country.append(response['sys']['country'])
        api_date.append(response['dt'])
        
        if counter_1 > 48:
            counter_1 = 1
            counter_2 += 1
            api_city.append(city)
        else:
            counter_1 += 1
            api_city.append(city)
        print(f"Processing Record {counter_1} of Set {counter_2} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | kjollefjord
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 1 | najran
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | richards bay
# Processing Record 7 of Set 1 | kavieng
# City not found. Skipping...
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | pochutla
# City not found. Skipping...
# Processing Record 11 of Set 1 | zhigansk
# Processing Record 12 of Set 1 | young
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | flinders
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | tsiroanomandidy
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | husavik
# City not found. Skipping...
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | cristobal obregon
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | nikolayevsk-na-amure
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 26 of Set 1 | ust-tsilma
# Processing Record 27 of Set 1 | omsukchan
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | kasongo-lunda
# Processing Record 30 of Set 1 | yambio
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | dubbo
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | hamilton
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | necochea
# City not found. Skipping...
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | bellary
# Processing Record 43 of Set 1 | hofn
# Processing Record 44 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | magdalena
# Processing Record 48 of Set 1 | puerto penasco
# Processing Record 49 of Set 1 | akcakoca
# Processing Record 1 of Set 2 | porto santo
# City not found. Skipping...
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | yabassi
# Processing Record 4 of Set 2 | raga
# Processing Record 5 of Set 2 | uchkeken
# City not found. Skipping...
# Processing Record 6 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 7 of Set 2 | buala
# Processing Record 8 of Set 2 | veraval
# City not found. Skipping...
# Processing Record 9 of Set 2 | gamba
# Processing Record 10 of Set 2 | tautira
# Processing Record 11 of Set 2 | kenai
# Processing Record 12 of Set 2 | talara
# Processing Record 13 of Set 2 | temiscaming
# Processing Record 14 of Set 2 | kirakira
# Processing Record 15 of Set 2 | dikson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 2 | mosetse
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | salekhard
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | council bluffs
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | amuntai
# Processing Record 24 of Set 2 | tuatapere
# Processing Record 25 of Set 2 | hobyo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 2 | moose factory
# Processing Record 27 of Set 2 | ndende
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | manadhoo
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | ust-kuyga
# Processing Record 33 of Set 2 | dingle
# Processing Record 34 of Set 2 | muzhi
# Processing Record 35 of Set 2 | ortona
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | ust-ordynskiy
# Processing Record 38 of Set 2 | naousa
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | manjo
# Processing Record 42 of Set 2 | lhokseumawe
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | hearst
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | itoman
# Processing Record 48 of Set 2 | milkovo
# Processing Record 49 of Set 2 | carnot
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | opuwo
# City not found. Skipping...
# Processing Record 3 of Set 3 | hatillo
# City not found. Skipping...
# Processing Record 4 of Set 3 | yinchuan
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | ibra
# Processing Record 7 of Set 3 | acapulco
# Processing Record 8 of Set 3 | carnarvon
# City not found. Skipping...
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | sinnamary
# Processing Record 11 of Set 3 | raudeberg
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | yumen
# Processing Record 14 of Set 3 | oranjemund
# Processing Record 15 of Set 3 | elizabeth city
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | manzanillo
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | salinas
# Processing Record 21 of Set 3 | kahului
# Processing Record 22 of Set 3 | biak
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | smoky lake
# Processing Record 25 of Set 3 | oksfjord
# Processing Record 26 of Set 3 | meaux
# Processing Record 27 of Set 3 | shenkursk
# City not found. Skipping...
# Processing Record 28 of Set 3 | qaqortoq
# Processing Record 29 of Set 3 | hobart
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | bacolod
# Processing Record 33 of Set 3 | williams lake
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | zalantun
# Processing Record 37 of Set 3 | ixtapa
# Processing Record 38 of Set 3 | bihoro
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | kobayashi
# City not found. Skipping...
# Processing Record 41 of Set 3 | mys shmidta
# Processing Record 42 of Set 3 | sercaia
# Processing Record 43 of Set 3 | anadyr
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | pedernales
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | muros
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | rochelle
# Processing Record 1 of Set 4 | bud
# Processing Record 2 of Set 4 | naze
# Processing Record 3 of Set 4 | grand river south east
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | sao filipe
# City not found. Skipping...
# Processing Record 8 of Set 4 | dombarovskiy
# Processing Record 9 of Set 4 | grand gaube
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | shaunavon
# City not found. Skipping...
# Processing Record 12 of Set 4 | williston
# Processing Record 13 of Set 4 | fairbanks
# Processing Record 14 of Set 4 | hare bay
# Processing Record 15 of Set 4 | parasia
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | constitucion
# City not found. Skipping...
# Processing Record 18 of Set 4 | mangrol
# Processing Record 19 of Set 4 | bur gabo
# Processing Record 20 of Set 4 | areka
# Processing Record 21 of Set 4 | ornes
# Processing Record 22 of Set 4 | vila franca do campo
# Processing Record 23 of Set 4 | praia
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | portland
# Processing Record 26 of Set 4 | maragogi
# Processing Record 27 of Set 4 | jalu
# Processing Record 28 of Set 4 | jiuquan
# City not found. Skipping...
# Processing Record 29 of Set 4 | coihaique
# City not found. Skipping...
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | balaipungut
# Processing Record 32 of Set 4 | severnyy
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | vostok
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | antofagasta
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | tuy hoa
# Processing Record 39 of Set 4 | anton lizardo
# Processing Record 40 of Set 4 | tynda
# City not found. Skipping...
# Processing Record 41 of Set 4 | amga
# Processing Record 42 of Set 4 | tabuk
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | eyl
# City not found. Skipping...
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | laje
# Processing Record 48 of Set 4 | mantova
# Processing Record 49 of Set 4 | korla
# Processing Record 1 of Set 5 | pangody
# Processing Record 2 of Set 5 | mattru
# Processing Record 3 of Set 5 | norilsk
# Processing Record 4 of Set 5 | changying
# Processing Record 5 of Set 5 | grants
# Processing Record 6 of Set 5 | isangel
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | oriximina
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | kedrovyy
# Processing Record 11 of Set 5 | bukachacha
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | ponnani
# Processing Record 14 of Set 5 | hay river
# Processing Record 15 of Set 5 | sulphur springs
# Processing Record 16 of Set 5 | sao joao da barra
# Processing Record 17 of Set 5 | araouane
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | wainwright
# Processing Record 21 of Set 5 | datong
# Processing Record 22 of Set 5 | champerico
# Processing Record 23 of Set 5 | abu kamal
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | vangaindrano
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | bhikangaon
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | jijiga
# Processing Record 31 of Set 5 | methven
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | xapuri
# Processing Record 34 of Set 5 | kashi
# Processing Record 35 of Set 5 | muisne
# City not found. Skipping...
# Processing Record 36 of Set 5 | male
# City not found. Skipping...
# Processing Record 37 of Set 5 | bonavista
# Processing Record 38 of Set 5 | koutsouras
# Processing Record 39 of Set 5 | povolzhskiy
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | palana
# Processing Record 42 of Set 5 | maracacume
# Processing Record 43 of Set 5 | hovd
# Processing Record 44 of Set 5 | azua
# Processing Record 45 of Set 5 | hervey bay
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | tessalit
# Processing Record 48 of Set 5 | shanhetun
# Processing Record 49 of Set 5 | pingliang
# Processing Record 1 of Set 6 | lillooet
# Processing Record 2 of Set 6 | rocha
# Processing Record 3 of Set 6 | maun
# City not found. Skipping...
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | pangoa
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | grand island
# City not found. Skipping...
# Processing Record 8 of Set 6 | dengfeng
# Processing Record 9 of Set 6 | saint-philippe
# Processing Record 10 of Set 6 | pombia
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | ewo
# Processing Record 13 of Set 6 | arvin
# Processing Record 14 of Set 6 | san angelo
# Processing Record 15 of Set 6 | balikpapan
# City not found. Skipping...
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | samarai
# Processing Record 18 of Set 6 | ahipara
# City not found. Skipping...
# Processing Record 19 of Set 6 | agadez
# Processing Record 20 of Set 6 | verkhnyaya sinyachikha
# City not found. Skipping...
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | huarmey
# Processing Record 23 of Set 6 | tricase
# Processing Record 24 of Set 6 | aksarayskiy
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | novaya ladoga
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | mumford
# City not found. Skipping...
# Processing Record 29 of Set 6 | alice springs
# City not found. Skipping...
# Processing Record 30 of Set 6 | auki
# Processing Record 31 of Set 6 | dumas
# Processing Record 32 of Set 6 | taybad
# Processing Record 33 of Set 6 | filingue
# Processing Record 34 of Set 6 | jardim
# Processing Record 35 of Set 6 | kamogawa
# Processing Record 36 of Set 6 | bageshwar
# Processing Record 37 of Set 6 | bontang
# Processing Record 38 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | nivala
# Processing Record 41 of Set 6 | krasnozerskoye
# Processing Record 42 of Set 6 | alsfeld
# City not found. Skipping...
# Processing Record 43 of Set 6 | minsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 6 | mabaruma
# Processing Record 45 of Set 6 | vytegra
# Processing Record 46 of Set 6 | tadine
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | norrkoping
# Processing Record 49 of Set 6 | hami
# City not found. Skipping...
# Processing Record 1 of Set 7 | teguise
# Processing Record 2 of Set 7 | avera
# Processing Record 3 of Set 7 | nome
# City not found. Skipping...
# Processing Record 4 of Set 7 | mwingi
# Processing Record 5 of Set 7 | lagoa
# Processing Record 6 of Set 7 | vanimo
# Processing Record 7 of Set 7 | northam
# City not found. Skipping...
# Processing Record 8 of Set 7 | inverell
# Processing Record 9 of Set 7 | waddan
# Processing Record 10 of Set 7 | mnogovershinnyy
# Processing Record 11 of Set 7 | bereda
# City not found. Skipping...
# Processing Record 12 of Set 7 | haines junction
# Processing Record 13 of Set 7 | padang
# Processing Record 14 of Set 7 | barroquinha
# Processing Record 15 of Set 7 | saint-pierre
# Processing Record 16 of Set 7 | naifaru
# Processing Record 17 of Set 7 | poum
# City not found. Skipping...
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | sistranda
# Processing Record 20 of Set 7 | pemangkat
# Processing Record 21 of Set 7 | krasnyy yar
# Processing Record 22 of Set 7 | sur
# Processing Record 23 of Set 7 | weligama
# Processing Record 24 of Set 7 | natal
# Processing Record 25 of Set 7 | mackay
# Processing Record 26 of Set 7 | bielsko-biala
# Processing Record 27 of Set 7 | ancud
# Processing Record 28 of Set 7 | barra patuca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 | terney
# City not found. Skipping...
# Processing Record 30 of Set 7 | lianran
# Processing Record 31 of Set 7 | angoche
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | kaoma
# Processing Record 34 of Set 7 | keflavik
# Processing Record 35 of Set 7 | guerrero negro
# Processing Record 36 of Set 7 | xinmin
# Processing Record 37 of Set 7 | suraabad
# Processing Record 38 of Set 7 | yuancheng
# Processing Record 39 of Set 7 | harper
# Processing Record 40 of Set 7 | poronaysk
# Processing Record 41 of Set 7 | vao
# Processing Record 42 of Set 7 | port blair
# Processing Record 43 of Set 7 | banda aceh
# Processing Record 44 of Set 7 | nishihara
# City not found. Skipping...
# Processing Record 45 of Set 7 | oswego
# Processing Record 46 of Set 7 | sorland
# Processing Record 47 of Set 7 | olden
# Processing Record 48 of Set 7 | pevek
# Processing Record 49 of Set 7 | abu dhabi
# Processing Record 1 of Set 8 | sorong
# Processing Record 2 of Set 8 | arman
# City not found. Skipping...
# Processing Record 3 of Set 8 | sao felix do xingu
# Processing Record 4 of Set 8 | labuhan
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | chara
# Processing Record 8 of Set 8 | gizo
# Processing Record 9 of Set 8 | rafai
# Processing Record 10 of Set 8 | villa bruzual
# Processing Record 11 of Set 8 | hazorasp
# Processing Record 12 of Set 8 | ambilobe
# City not found. Skipping...
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | sioux lookout
# Processing Record 15 of Set 8 | gat
# City not found. Skipping...
# Processing Record 16 of Set 8 | coquimbo
# Processing Record 17 of Set 8 | port said
# Processing Record 18 of Set 8 | hue
# Processing Record 19 of Set 8 | kununurra
# Processing Record 20 of Set 8 | selizharovo
# Processing Record 21 of Set 8 | tukrah
# Processing Record 22 of Set 8 | ipinda
# Processing Record 23 of Set 8 | ponta do sol
# Processing Record 24 of Set 8 | namwala
# Processing Record 25 of Set 8 | amantea
# Processing Record 26 of Set 8 | arinos
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | tangshan
# City not found. Skipping...
# Processing Record 29 of Set 8 | gorontalo
# Processing Record 30 of Set 8 | kalmunai
# Processing Record 31 of Set 8 | smithers
# City not found. Skipping...
# Processing Record 32 of Set 8 | nanakuli
# City not found. Skipping...
# Processing Record 33 of Set 8 | porterville
# Processing Record 34 of Set 8 | yuryev-polskiy
# Processing Record 35 of Set 8 | aklavik
# Processing Record 36 of Set 8 | beloha
# Processing Record 37 of Set 8 | port moresby
# Processing Record 38 of Set 8 | craigieburn
# Processing Record 39 of Set 8 | ustka
# Processing Record 40 of Set 8 | bireun
# Processing Record 41 of Set 8 | port hardy
# Processing Record 42 of Set 8 | corinto
# Processing Record 43 of Set 8 | kang
# Processing Record 44 of Set 8 | igarka
# Processing Record 45 of Set 8 | russellville
# Processing Record 46 of Set 8 | oxford
# Processing Record 47 of Set 8 | kloulklubed
# City not found. Skipping...
# Processing Record 48 of Set 8 | souillac
# Processing Record 49 of Set 8 | ovejas
# City not found. Skipping...
# Processing Record 1 of Set 9 | witu
# Processing Record 2 of Set 9 | porto san giorgio
# Processing Record 3 of Set 9 | maldonado
# Processing Record 4 of Set 9 | belaya gora
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | adrar
# City not found. Skipping...
# Processing Record 7 of Set 9 | buraydah
# Processing Record 8 of Set 9 | anshun
# Processing Record 9 of Set 9 | disna
# Processing Record 10 of Set 9 | iberia
# City not found. Skipping...
# Processing Record 11 of Set 9 | broome
# Processing Record 12 of Set 9 | iralaya
# Processing Record 13 of Set 9 | taunggyi
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | lasa
# Processing Record 16 of Set 9 | zhangjiakou
# Processing Record 17 of Set 9 | ozieri
# Processing Record 18 of Set 9 | sambava
# Processing Record 19 of Set 9 | faya
# City not found. Skipping...
# Processing Record 20 of Set 9 | dukat
# Processing Record 21 of Set 9 | kokkola
# Processing Record 22 of Set 9 | axim
# Processing Record 23 of Set 9 | montrose
# Processing Record 24 of Set 9 | ust-kut
# Processing Record 25 of Set 9 | santiago
# Processing Record 26 of Set 9 | xining
# Processing Record 27 of Set 9 | santa isabel
# Processing Record 28 of Set 9 | jashpurnagar
# Processing Record 29 of Set 9 | san carlos de bariloche
# Processing Record 30 of Set 9 | cockburn harbour
# Processing Record 31 of Set 9 | doha
# City not found. Skipping...
# Processing Record 32 of Set 9 | bokaro
# Processing Record 33 of Set 9 | bayamo
# Processing Record 34 of Set 9 | sibiti
# Processing Record 35 of Set 9 | karpathos
# Processing Record 36 of Set 9 | pacifica
# Processing Record 37 of Set 9 | marystown
# Processing Record 38 of Set 9 | paamiut
# Processing Record 39 of Set 9 | daru
# Processing Record 40 of Set 9 | ostersund
# Processing Record 41 of Set 9 | yongan
# Processing Record 42 of Set 9 | elko
# Processing Record 43 of Set 9 | chegdomyn
# Processing Record 44 of Set 9 | antalaha
# Processing Record 45 of Set 9 | panguna
# Processing Record 46 of Set 9 | kerman
# Processing Record 47 of Set 9 | riverton
# Processing Record 48 of Set 9 | deputatskiy
# Processing Record 49 of Set 9 | itupiranga
# Processing Record 1 of Set 10 | susanville
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | gouyave
# Processing Record 4 of Set 10 | namatanai
# Processing Record 5 of Set 10 | narasannapeta
# Processing Record 6 of Set 10 | moron
# Processing Record 7 of Set 10 | san vicente
# Processing Record 8 of Set 10 | sulangan
# Processing Record 9 of Set 10 | tieli
# Processing Record 10 of Set 10 | norfolk
# Processing Record 11 of Set 10 | kidal
# Processing Record 12 of Set 10 | westport
# Processing Record 13 of Set 10 | dandong
# Processing Record 14 of Set 10 | yeppoon
# Processing Record 15 of Set 10 | takoradi
# Processing Record 16 of Set 10 | nioro
# Processing Record 17 of Set 10 | saint-francois
# Processing Record 18 of Set 10 | vysokovsk
# Processing Record 19 of Set 10 | jiexiu
# Processing Record 20 of Set 10 | markala
# Processing Record 21 of Set 10 | nemuro
# Processing Record 22 of Set 10 | dodge city
# Processing Record 23 of Set 10 | wajima
# Processing Record 24 of Set 10 | rawson
# Processing Record 25 of Set 10 | taltal
# Processing Record 26 of Set 10 | vila
# Processing Record 27 of Set 10 | cap malheureux
# Processing Record 28 of Set 10 | vestmannaeyjar
# Processing Record 29 of Set 10 | mayo
# Processing Record 30 of Set 10 | kiunga
# Processing Record 31 of Set 10 | glendive
# Processing Record 32 of Set 10 | puerto leguizamo
# Processing Record 33 of Set 10 | lamu
# Processing Record 34 of Set 10 | terrace
# Processing Record 35 of Set 10 | odweyne
# Processing Record 36 of Set 10 | emba
# Processing Record 37 of Set 10 | zhob
# Processing Record 38 of Set 10 | russell
# Processing Record 39 of Set 10 | decatur
# Processing Record 40 of Set 10 | san jeronimo
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | ciro marina
# Processing Record 43 of Set 10 | buchanan
# Processing Record 44 of Set 10 | peniche
# Processing Record 45 of Set 10 | ostrow mazowiecka
# City not found. Skipping...
# Processing Record 46 of Set 10 | byron bay
# Processing Record 47 of Set 10 | griffith
# Processing Record 48 of Set 10 | valenca do piaui
# Processing Record 49 of Set 10 | campbell river
# Processing Record 1 of Set 11 | cascais
# Processing Record 2 of Set 11 | kodinsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | faanui
# Processing Record 5 of Set 11 | puerto escondido
# City not found. Skipping...
# Processing Record 6 of Set 11 | buluang
# Processing Record 7 of Set 11 | tecoanapa
# Processing Record 8 of Set 11 | borogontsy
# Processing Record 9 of Set 11 | xushan
# Processing Record 10 of Set 11 | volovo
# Processing Record 11 of Set 11 | harrismith
# Processing Record 12 of Set 11 | gitarama
# Processing Record 13 of Set 11 | manono
# Processing Record 14 of Set 11 | ovalle
# Processing Record 15 of Set 11 | sarangani
# Processing Record 16 of Set 11 | lethem
# Processing Record 17 of Set 11 | moroni
# City not found. Skipping...
# Processing Record 18 of Set 11 | zyryanka
# Processing Record 19 of Set 11 | kaduqli
# Processing Record 20 of Set 11 | iqaluit
# Processing Record 21 of Set 11 | cambados
# Processing Record 22 of Set 11 | yagodnoye
# Processing Record 23 of Set 11 | acandi
# Processing Record 24 of Set 11 | karpogory
# Processing Record 25 of Set 11 | subang
# City not found. Skipping...
# Processing Record 26 of Set 11 | takaka
# Processing Record 27 of Set 11 | wadi musa
# Processing Record 28 of Set 11 | matara
# Processing Record 29 of Set 11 | togur
# Processing Record 30 of Set 11 | durham
# Processing Record 31 of Set 11 | arica
# Processing Record 32 of Set 11 | watertown
# Processing Record 33 of Set 11 | shobara
# Processing Record 34 of Set 11 | meadville
# Processing Record 35 of Set 11 | poya
# Processing Record 36 of Set 11 | tigzirt
# City not found. Skipping...
# Processing Record 37 of Set 11 | visby
# Processing Record 38 of Set 11 | constantine
# Processing Record 39 of Set 11 | tevaitoa
# Processing Record 40 of Set 11 | tilichiki
# Processing Record 41 of Set 11 | maniitsoq
# Processing Record 42 of Set 11 | kolyvan
# Processing Record 43 of Set 11 | morgan city
# Processing Record 44 of Set 11 | taloqan
# Processing Record 45 of Set 11 | brae
# City not found. Skipping...
# Processing Record 46 of Set 11 | belmonte
# Processing Record 47 of Set 11 | hasanabad
# Processing Record 48 of Set 11 | marica
# Processing Record 49 of Set 11 | acari
# Processing Record 1 of Set 12 | yerbogachen
# Processing Record 2 of Set 12 | nachingwea
# Processing Record 3 of Set 12 | san jose
# Processing Record 4 of Set 12 | dana point
# City not found. Skipping...
# Processing Record 5 of Set 12 | verkhnyaya inta
# Processing Record 6 of Set 12 | brigantine
# Processing Record 7 of Set 12 | singaparna
# Processing Record 8 of Set 12 | san rafael
# Processing Record 9 of Set 12 | camacha
# Processing Record 10 of Set 12 | altay
# Processing Record 11 of Set 12 | ondangwa
# Processing Record 12 of Set 12 | limache
# Processing Record 13 of Set 12 | lavras da mangabeira
# Processing Record 14 of Set 12 | emerald
# Processing Record 15 of Set 12 | talcahuano
# Processing Record 16 of Set 12 | kholmogory
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | kalmar
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary to store into df
weather_dict = {
    "City":api_city,
    "Lat":api_lat,
    "Lng":api_lng,
    "Max Temp":api_temp_max,
    "Humidity":api_humidity,
    "Cloudiness":api_cloud,
    "Wind Speed":api_wspeed,
    "Country":api_country,
    "Date":api_date
}

weather_df = pd.DataFrame(weather_dict)

weather_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    busselton -33.6500  115.3333     61.00        94         100        3.00
# 1        vaini -21.2000 -175.2000     82.40        83          75        9.22
# 2  kjollefjord  70.9457   27.3465     25.84        94         100       22.41
# 3       najran  17.4924   44.1277     57.20        54           0        4.61
# 4         hilo  19.7297 -155.0900     75.20        57          90        6.91
#
#   Country        Date
# 0      AU  1612671072
# 1      TO  1612671178
# 2      NO  1612671179
# 3      SA  1612670940
# 4      US  1612671180

# %%
#save in csv file
weather_df.to_csv(output_data_file)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    23.080903   20.010887   48.100305   73.224417   53.057451    7.796032
# std     31.499670   88.316228   31.582346   20.388447   40.001532    5.428411
# min    -54.800000 -175.200000  -43.010000    1.000000    0.000000    0.490000
# 25%     -2.271700  -55.148300   28.400000   64.000000    5.000000    3.710000
# 50%     29.850000   22.787600   57.200000   79.000000   66.000000    6.820000
# 75%     47.866700   96.700900   73.990000   88.000000   90.000000   10.360000
# max     78.218600  177.483300   99.000000  100.000000  100.000000   33.330000
#
#                Date
# count  5.570000e+02
# mean   1.612671e+09
# std    9.722734e+01
# min    1.612671e+09
# 25%    1.612671e+09
# 50%    1.612671e+09
# 75%    1.612671e+09
# max    1.612671e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#In the previous output, max humidity is 100

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], alpha = 1/4)
plt.title("City Latitude vs. Max Temperature on 2/5/2021")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both")
plt.savefig("Images/Lat_MaxTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],alpha = 1/2)
plt.title("City Latitude vs. Humidity on 2/5/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid (b=True,which="major",axis="both")
plt.savefig("Images/Lat_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], alpha = 1/3)
plt.title("City Latitude vs. Cloudiness on 2/5/2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both")
plt.savefig("Images/Lat_Cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],alpha= 1/3)
plt.title("City Latitude vs. Wind Speed on 2/5/2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Images/Lat_wspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#define north and souther hemisphere
north_hemi = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) > 0, :]
south_hemi = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemi['Lat']
y_values = north_hemi['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Maximum Tempature')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7435535505113762

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemi['Lat']
y_values = south_hemi['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Maximum Tempature')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.24829727022521558

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi['Lat']
y_values = north_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.11792060699946348

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemi['Lat']
y_values = south_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.013736986168449582

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi['Lat']
y_values = north_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03942369302933203

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemi['Lat']
y_values = south_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1101388936229827

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemi['Lat']
y_values = north_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02009462238847724

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemi['Lat']
y_values = south_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03861475796007046
